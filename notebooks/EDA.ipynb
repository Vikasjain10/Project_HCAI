# %%
import os

folders = os.listdir("../data/raw")

print(folders)
# Out:
# ['p01', 'p02', 'p03', 'p04', 'p05', 'p06', 'p07', 'p08', 'p09', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16']

# %%
import os
import pandas as pd

# 1. Test if Python can see all 16 participant folders
raw_path = "../data/raw"
folders = sorted(os.listdir(raw_path))
print("✅ Folders found:", folders)

# 2. Test if Python can read the subjective labels (stress/fatigue)
wellness_p01 = pd.read_csv("../data/raw/p01/wellness.csv")
print("\n✅ p01 Wellness Data Loaded Successfully! First 3 rows:")
display(wellness_p01.head(3))
# Out:
# ✅ Folders found: ['p01', 'p02', 'p03', 'p04', 'p05', 'p06', 'p07', 'p08', 'p09', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16']
#
# ✅ p01 Wellness Data Loaded Successfully! First 3 rows:
#        effective_time_frame  fatigue  mood  readiness  sleep_duration_h  \
# 0  2019-11-01T08:31:40.751Z        2     3          5                 6
# 1  2019-11-02T10:00:01.229Z        2     3          6                 6
# 2  2019-11-03T14:28:03.263Z        3     3          8                 6
#
#    sleep_quality  soreness soreness_area  stress
# 0              3         2    [12921003]       3
# 1              3         2    [12921003]       3
# 2              3         3            []       3

# %%
import json

with open(
    "../data/raw/p01/heart_rate.json"
) as f:

    data = json.load(f)

print(data[:5])
# Out:
# [{'dateTime': '2019-11-01 00:00:05', 'value': {'bpm': 54, 'confidence': 3}}, {'dateTime': '2019-11-01 00:00:10', 'value': {'bpm': 52, 'confidence': 3}}, {'dateTime': '2019-11-01 00:00:20', 'value': {'bpm': 51, 'confidence': 3}}, {'dateTime': '2019-11-01 00:00:25', 'value': {'bpm': 52, 'confidence': 3}}, {'dateTime': '2019-11-01 00:00:30', 'value': {'bpm': 51, 'confidence': 3}}]

# %%
import pandas as pd

# 1. Load the data into memory so Python knows what it is
wellness = pd.read_csv("../data/raw/p01/wellness.csv")

# 2. Now ask for the info
wellness.info()
wellness.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   effective_time_frame  138 non-null    object
#  1   fatigue               138 non-null    int64
#  2   mood                  138 non-null    int64
#  3   readiness             138 non-null    int64
#  4   sleep_duration_h      138 non-null    int64
#  5   sleep_quality         138 non-null    int64
#  6   soreness              138 non-null    int64
#  7   soreness_area         138 non-null    object
#  8   stress                138 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 9.8+ KB
#           fatigue        mood   readiness  sleep_duration_h  sleep_quality  \
# count  138.000000  138.000000  138.000000        138.000000     138.000000
# mean     2.565217    2.963768    6.224638          5.500000       2.724638
# ...
